# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dia=sns.load_dataset("diamonds")
dia.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
penguins=sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# # scatterplot(num~num)

# %%
sns.scatterplot(x=penguins["bill_depth_mm"],y=penguins["body_mass_g"],hue=penguins["sex"],style=penguins["species"],size=penguins["flipper_length_mm"])
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='body_mass_g'>

# %%
dia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %% [markdown]
# # barplot (num~categorical)

# %%
sns.barplot(x=dia["color"],y=dia["carat"],hue=dia["cut"])
# Out:
# <Axes: xlabel='color', ylabel='carat'>

# %% [markdown]
# # box plot(num~cat)

# %%
sns.boxplot(x=penguins["sex"],y=penguins["bill_depth_mm"],hue=penguins["island"])
# Out:
# <Axes: xlabel='sex', ylabel='bill_depth_mm'>

# %% [markdown]
# # displot(num~cate)

# %%
tit=sns.load_dataset("titanic")
tit.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.distplot(tit[tit["survived"]==0]["age"],hist=False)
sns.distplot(tit[tit["survived"]==1]["age"],hist=False)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_9112\675848302.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tit[tit["survived"]==0]["age"],hist=False)
# C:\Users\pc\AppData\Local\Temp\ipykernel_9112\675848302.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# # heatmap (categorical~categorical)

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
pd.crosstab(penguins["island"],penguins["sex"])
# Out:
# sex        Female  Male
# island
# Biscoe         80    83
# Dream          61    62
# Torgersen      24    23

# %%
sns.heatmap(pd.crosstab(penguins["sex"],penguins['island']))
# Out:
# <Axes: xlabel='island', ylabel='sex'>

# %%
penguins.pivot_table(values= "flipper_length_mm",index="species",columns="sex")
# Out:
# sex            Female        Male
# species
# Adelie     187.794521  192.410959
# Chinstrap  191.735294  199.911765
# Gentoo     212.706897  221.540984

# %%
tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.heatmap(tit.pivot_table(values="pclass",index="survived",columns="age"))
# Out:
# <Axes: xlabel='age', ylabel='survived'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
tit.groupby("pclass")["survived"].mean() * 100
# Out:
# pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: survived, dtype: float64

# %%
(tit.groupby("embarked")["survived"].mean()*100).plot(kind="bar",color="red")
# Out:
# <Axes: xlabel='embarked'>

# %%
import seaborn as sns
from ydata_profiling import ProfileReport

df = sns.load_dataset("flights")   # seaborn dataset
profile = ProfileReport(df)
profile.to_file("report.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 317.15it/s]

# %%
ir=sns.load_dataset("iris")
ir.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
pd.crosstab(tit["sibsp"],tit["survived"])
#crosstab() is used to analyze the relationship between two categorical variables by creating a frequency table (count table).
# Out:
# survived    0    1
# sibsp
# 0         398  210
# 1          97  112
# 2          15   13
# 3          12    4
# 4          15    3
# 5           5    0
# 8           7    0

# %%
sns.clustermap(pd.crosstab(tit["pclass"],tit["sibsp"]))

# %%
tit.pivot_table(values="fare",index="class",columns="sibsp")
#advanced version of crosstab.
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_9760\1383503022.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   tit.pivot_table(values="fare",index="class",columns="sibsp")
# sibsp           0          1           2           3          4     5      8
# class
# First   75.223356  88.492021  159.975840  263.000000        NaN   NaN    NaN
# Second  15.532327  28.385682   44.468750   21.000000        NaN   NaN    NaN
# Third    9.832689  16.658487   19.564993   24.378483  31.855556  46.9  69.55

# %%
tit.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.heatmap(tit.pivot_table(values="fare",index="class",columns="sibsp"))
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_9760\1528473497.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(tit.pivot_table(values="fare",index="class",columns="sibsp"))
# <Axes: xlabel='sibsp', ylabel='class'>

# %% [markdown]
# ## pairplot

# %%
ir.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(ir,hue="sepal_length")
#it is used for visualizing relationships between multiple numerical variables at once
